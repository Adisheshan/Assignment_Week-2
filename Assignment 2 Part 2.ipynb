# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
arr = np.random.rand(100) 
plt.hist(arr, rwidth=0.8)    # The shape of this histogram is non uniform because here size is small and we can clearly see the differences in frequencies
# Out:
# (array([11.,  7., 10., 10., 13.,  9.,  8., 14., 11.,  7.]),
#  array([0.00620591, 0.1044946 , 0.20278329, 0.30107198, 0.39936067,
#         0.49764936, 0.59593805, 0.69422674, 0.79251543, 0.89080412,
#         0.98909281]),
#  <a list of 10 Patch objects>)

# %%
arr1 = np.random.rand(500)
plt.hist(arr1, rwidth=0.8)
# Out:
# (array([46., 46., 57., 59., 48., 53., 47., 47., 50., 47.]),
#  array([0.00469598, 0.10410271, 0.20350943, 0.30291615, 0.40232288,
#         0.5017296 , 0.60113632, 0.70054305, 0.79994977, 0.89935649,
#         0.99876321]),
#  <a list of 10 Patch objects>)

# %%
arr2.random.rand(1000)
plt.hist(arr2, rwidth=0.8)
# Out:
# (array([ 88., 111.,  83., 118.,  95., 112.,  98., 105.,  95.,  95.]),
#  array([1.47142675e-04, 1.00064372e-01, 1.99981602e-01, 2.99898832e-01,
#         3.99816061e-01, 4.99733291e-01, 5.99650521e-01, 6.99567750e-01,
#         7.99484980e-01, 8.99402209e-01, 9.99319439e-01]),
#  <a list of 10 Patch objects>)

# %%
arr3 = np.random.rand(2000)
plt.hist(arr3, rwidth=0.8)
# Out:
# (array([184., 194., 205., 226., 196., 197., 190., 205., 209., 194.]),
#  array([6.51669860e-04, 1.00551459e-01, 2.00451248e-01, 3.00351038e-01,
#         4.00250827e-01, 5.00150616e-01, 6.00050405e-01, 6.99950195e-01,
#         7.99849984e-01, 8.99749773e-01, 9.99649562e-01]),
#  <a list of 10 Patch objects>)

# %%
arr4 = np.random.rand(5000)
plt.hist(arr4, rwidth=0.8) # As the size of the list is increasing we can clearly see that the shape is coming as uniform.
# Out:
# (array([496., 470., 496., 506., 486., 524., 527., 463., 500., 532.]),
#  array([6.47547013e-04, 1.00565269e-01, 2.00482990e-01, 3.00400712e-01,
#         4.00318433e-01, 5.00236155e-01, 6.00153876e-01, 7.00071598e-01,
#         7.99989320e-01, 8.99907041e-01, 9.99824763e-01]),
#  <a list of 10 Patch objects>)

# %%
ARR=np.random.normal(size=100)
plt.hist(ARR)
# Out:
# (array([ 6.,  3.,  1., 13., 14., 26., 16., 13.,  5.,  3.]),
#  array([-2.65463595, -2.12805637, -1.60147678, -1.0748972 , -0.54831762,
#         -0.02173804,  0.50484154,  1.03142112,  1.5580007 ,  2.08458028,
#          2.61115986]),
#  <a list of 10 Patch objects>)

# %%
ARR1 = np.random.normal(size=1000)
plt.hist(ARR1)
# Out:
# (array([  6.,  20.,  83., 163., 251., 264., 147.,  44.,  18.,   4.]),
#  array([-3.2470333 , -2.58257556, -1.91811782, -1.25366007, -0.58920233,
#          0.07525541,  0.73971315,  1.4041709 ,  2.06862864,  2.73308638,
#          3.39754413]),
#  <a list of 10 Patch objects>)

# %%
ARR2=np.random.normal(size=5000)
plt.hist(ARR2)
# Out:
# (array([   6.,   35.,  221.,  764., 1453., 1523.,  774.,  198.,   24.,
#            2.]),
#  array([-4.19286174, -3.34866107, -2.5044604 , -1.66025973, -0.81605906,
#          0.02814161,  0.87234228,  1.71654295,  2.56074362,  3.40494429,
#          4.24914495]),
#  <a list of 10 Patch objects>)

# %%
# Here the shape of the distribution is normal and as we are increasing the size of the sample list the distribution is getting more uniform.
